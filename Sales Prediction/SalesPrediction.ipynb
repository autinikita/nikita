# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
sales_data = pd.read_csv(r"advertising.csv")
sales_data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
sales_data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
sales_data.describe()   # Desribing statistical measures
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sales_data.isnull()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
sales_data.isnull().sum()

# There are no null values in the dataset, hence it is cleaned.
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
sales_data = sales_data.astype("int")   # converting float values into int 
sales_data.head()
# Out:
#     TV  Radio  Newspaper  Sales
# 0  230     37         69     22
# 1   44     39         45     10
# 2   17     45         69     12
# 3  151     41         58     16
# 4  180     10         58     17

# %%
type(sales_data["Newspaper"])   # Fetching datatype of Newspaper column
# Out:
# pandas.core.series.Series

# %%
sales_data["Sales"].mean()   # Finding mean of Sales column
# Out:
# 14.665

# %%
sales_data["Sales"].std()   # Finding standard deviation of Sales column
# Out:
# 5.2908164486653035

# %%
sales_data["ProductQty"] = "5"   # New column added named ProductQty
sales_data.head()
# Out:
#     TV  Radio  Newspaper  Sales ProductQty
# 0  230     37         69     22          5
# 1   44     39         45     10          5
# 2   17     45         69     12          5
# 3  151     41         58     16          5
# 4  180     10         58     17          5

# %%
sales_data.duplicated(subset = ["TV","Newspaper","Radio"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
sales_data["TV"].add(10)
# Out:
# 0      240
# 1       54
# 2       27
# 3      161
# 4      190
#       ...
# 195     48
# 196    104
# 197    187
# 198    293
# 199    242
# Name: TV, Length: 200, dtype: int32

# %%
sales_data["Radio"].div(2)
# Out:
# 0      18.5
# 1      19.5
# 2      22.5
# 3      20.5
# 4       5.0
#        ...
# 195     1.5
# 196     2.0
# 197     4.5
# 198    21.0
# 199     4.0
# Name: Radio, Length: 200, dtype: float64

# %%
sales_data.iloc[0:100:10]     # slicing
# Out:
#      TV  Radio  Newspaper  Sales ProductQty
# 0   230     37         69     22          5
# 10   66      5         24     12          5
# 20  218     27         53     18          5
# 30  292     28         43     21          5
# 40  202     22         31     16          5
# 50  199      3         34     16          5
# 60   53      2         21      8          5
# 70  199     30         38     18          5
# 80   76     26         22     11          5
# 90  134      4          9     14          5

# %%
sales_data.sample(n=4)   # fetching 4 random samples
# Out:
#       TV  Radio  Newspaper  Sales ProductQty
# 88    88     25         73     12          5
# 161   85     35         49     13          5
# 53   182     46         58     21          5
# 143  104      5         34     10          5

# %%
# to plot multiple pairwise bivariate distributions in a dataset

sns.pairplot(sales_data,plot_kws={"color":"#82ad32"})

# %%
sns.pairplot(sales_data,x_vars=["Newspaper","TV","Radio"],y_vars="Sales",kind="scatter",)
plt.show()

# %%
sns.distplot(sales_data["Sales"],color="lightseagreen")
# Out:
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
sns.jointplot(x="Newspaper",y="Sales",data = sales_data,color="rosybrown")

# %%
del sales_data["ProductQty"]

# %%
sales_data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.055388   0.055569  0.899568
# Radio      0.055388  1.000000   0.352552  0.355736
# Newspaper  0.055569  0.352552   1.000000  0.159715
# Sales      0.899568  0.355736   0.159715  1.000000

# %%
sns.heatmap(sales_data.corr(),annot = True)
plt.show()

# %%
# splitting the data into training and testing data

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(sales_data[["TV"]],sales_data[["Sales"]],test_size = 0.3,random_state=0)

# %%
print(x_train)
# Out:
#       TV
# 131  265
# 96   197
# 181  218
# 19   147
# 153  171
# ..   ...
# 67   139
# 192   17
# 117   76
# 47   239
# 172   19
#
# [140 rows x 1 columns]

# %%
print(y_train)
# Out:
#      Sales
# 131     17
# 96      16
# 181     17
# 19      14
# 153     16
# ..     ...
# 67      13
# 192      5
# 117      9
# 47      23
# 172      7
#
# [140 rows x 1 columns]

# %%
print(x_test)
# Out:
#       TV
# 18    69
# 170   50
# 107   90
# 98   289
# 177  170
# 182   56
# 5      8
# 146  240
# 12    23
# 152  197
# 61   261
# 125   87
# 180  156
# 154  187
# 80    76
# 7    120
# 33   265
# 130    0
# 37    74
# 74   213
# 183  287
# 145  140
# 45   175
# 159  131
# 60    53
# 123  123
# 179  165
# 185  205
# 122  224
# 44    25
# 16    67
# 55   198
# 150  280
# 111  241
# 22    13
# 189   18
# 129   59
# 4    180
# 83    68
# 106   25
# 134   36
# 66    31
# 26   142
# 113  209
# 168  215
# 63   102
# 8      8
# 75    16
# 118  125
# 143  104
# 71   109
# 124  229
# 184  253
# 97   184
# 149   44
# 24    62
# 30   292
# 160  172
# 40   202
# 56     7

# %%
print(y_test)
# Out:
#      Sales
# 18      11
# 170      8
# 107     12
# 98      25
# 177     16
# 182      8
# 5        7
# 146     18
# 12       9
# 152     16
# 61      24
# 125     10
# 180     15
# 154     20
# 80      11
# 7       13
# 33      17
# 130      1
# 37      14
# 74      17
# 183     26
# 145     10
# 45      16
# 159     12
# 60       8
# 123     15
# 179     17
# 185     22
# 122     16
# 44       8
# 16      12
# 55      23
# 150     16
# 111     21
# 22       5
# 189      6
# 129      9
# 4       17
# 83      13
# 106      7
# 134     10
# 66      11
# 26      15
# 113     20
# 168     17
# 63      14
# 8        4
# 75       8
# 118     15
# 143     10
# 71      12
# 124     19
# 184     17
# 97      20
# 149     10
# 24       9
# 30      21
# 160     16
# 40      16
# 56       5

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# predicting the dataset

res = model.predict(x_test)
print(res)
# Out:
# [[10.48631842]
#  [ 9.44824717]
#  [11.63366033]
#  [22.50609075]
#  [16.00448663]
#  [ 9.77605915]
#  [ 7.15356337]
#  [19.82895964]
#  [ 7.9730933 ]
#  [17.47964051]
#  [20.97630155]
#  [11.46975434]
#  [15.23959203]
#  [16.93328722]
#  [10.86876572]
#  [13.27272019]
#  [21.19484286]
#  [ 6.71648073]
#  [10.75949507]
#  [18.35380577]
#  [22.3968201 ]
#  [14.36542677]
#  [16.27766327]
#  [13.87370881]
#  [ 9.61215316]
#  [13.43662618]
#  [15.73130998]
#  [17.91672314]
#  [18.95479438]
#  [ 8.08236395]
#  [10.37704776]
#  [17.53427584]
#  [22.0143728 ]
#  [19.88359497]
#  [ 7.42674001]
#  [ 7.69991665]
#  [ 9.93996513]
#  [16.55083992]
#  [10.43168309]
#  [ 8.08236395]
#  [ 8.68335257]
#  [ 8.41017593]
#  [14.47469742]
#  [18.13526445]
#  [18.46307642]
#  [12.28928427]
#  [ 7.15356337]
#  [ 7.590646  ]
#  [13.54589683]
#  [12.39855493]
#  [12.67173157]
#  [19.22797103]
#  [20.53921892]
#  [16.76938123]
#  [ 9.1204352 ]
#  [10.10387112]
#  [22.66999674]
#  [16.11375729]
# ...

# %%
model.coef_
# Out:
# array([[0.05463533]])

# %%
model.intercept_
# Out:
# array([6.71648073])

# %%
0.05473199*90+7.14382225
# Out:
# 12.06970135
